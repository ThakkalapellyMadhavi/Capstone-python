# %%
#Importing the librariries
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sb                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation
import warnings 
warnings.filterwarnings('ignore')

# %%
#Reading data from csv file
df = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Number of rows and columns

# %%
df.shape
# Out:
# (4803, 20)

# %% [markdown]
# ### Display the names of all the columns

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# ### Reading the top 5 rows

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ### Reading the bottom 5 rows

# %%
df.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %% [markdown]
# ### Displaying the dataset information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# ### Separating Categorical and Numerical Variables

# %%
#seperating the categorical and Numerical data

def seperate_data_types(df):
    categorical=[]
    continuous=[]
    for columns in df.columns:
        if df[columns].nunique()<100:             #return the nunique values in the column 
            categorical.append(columns)         # 100 is hyperparameter
        else:
            continuous.append(columns)
    return categorical,continuous

categorical, continuous = seperate_data_types(df)

from tabulate import tabulate 
table=[categorical,continuous]
print(tabulate({"Categorical":categorical,"Continous":continuous},headers=["categorical","continuous"]))
# Out:
# categorical        continuous
# -----------------  --------------------
# original_language  budget
# status             genres
# vote_average       homepage
#                    id
#                    keywords
#                    original_title
#                    overview
#                    popularity
#                    production_companies
#                    production_countries
#                    release_date
#                    revenue
#                    runtime
#                    spoken_languages
#                    tagline
#                    title
#                    vote_count

# %% [markdown]
# ### Task 1

# %%
#converting the string representations to actual lists of dictionaries
import ast
df['genres']=df['genres'].apply(ast.literal_eval)

#extracting the genre name using a lambda function 
names=df['genres'].apply(lambda x:[genre['name'] for genre in x])

# %%
df1=df[['genres','original_title']].head(50).reset_index(drop=True)
df1.index+=1

# %%
df['genres']=names

# %% [markdown]
# ### Displaying the title and genres of the first 50 movies from the data set

# %%
df1=df[['genres','original_title']].head(50)
df1
# Out:
#                                                genres  \
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
# 5                        [Fantasy, Action, Adventure]
# 6                                 [Animation, Family]
# 7                [Action, Adventure, Science Fiction]
# 8                        [Adventure, Fantasy, Family]
# 9                        [Action, Adventure, Fantasy]
# 10      [Adventure, Fantasy, Action, Science Fiction]
# 11               [Adventure, Action, Thriller, Crime]
# 12                       [Adventure, Fantasy, Action]
# 13                       [Action, Adventure, Western]
# 14      [Action, Adventure, Fantasy, Science Fiction]
# 15                       [Adventure, Family, Fantasy]
# ...

# %% [markdown]
# ### Task 2

# %% [markdown]
# ### Checking if there are null values in any columns

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# ### Imputing the null value with mean for numerical column that is required for current data analysis

# %%
#replace the missing value by the mean value
df['runtime'] = df['runtime'].fillna(df['runtime'].mean())

# %% [markdown]
# ### After Imputation method

# %%
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# ### Task 3

# %%
df3=df[df.budget>220000]
df3
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 4680     450000                      [Crime, Horror, Thriller]
# 4682   13000000                                       [Horror]
# 4720    8500000                                        [Drama]
# 4758    4000000                    [Thriller, Science Fiction]
# 4770     500000                                [Drama, Comedy]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 1         http://disney.go.com/disneypictures/pirates/     285
# ...

# %% [markdown]
#  ### The movie categories that have a budget greater than $220000

# %%
df3[['genres','budget']]
# Out:
#                                              genres     budget
# 0     [Action, Adventure, Fantasy, Science Fiction]  237000000
# 1                      [Adventure, Fantasy, Action]  300000000
# 2                        [Action, Adventure, Crime]  245000000
# 3                  [Action, Crime, Drama, Thriller]  250000000
# 4              [Action, Adventure, Science Fiction]  260000000
# ...                                             ...        ...
# 4680                      [Crime, Horror, Thriller]     450000
# 4682                                       [Horror]   13000000
# 4720                                        [Drama]    8500000
# 4758                    [Thriller, Science Fiction]    4000000
# 4770                                [Drama, Comedy]     500000
#
# [3684 rows x 2 columns]

# %% [markdown]
# ### Task 4

# %%
df4=df[df.revenue>961000000]
df4
# Out:
#         budget                                          genres  \
# 0    237000000   [Action, Adventure, Fantasy, Science Fiction]
# 3    250000000                [Action, Crime, Drama, Thriller]
# 7    280000000            [Action, Adventure, Science Fiction]
# 12   200000000                    [Adventure, Fantasy, Action]
# 16   220000000            [Science Fiction, Action, Adventure]
# 17   380000000                    [Adventure, Action, Fantasy]
# 25   200000000                      [Drama, Romance, Thriller]
# 26   250000000            [Adventure, Action, Science Fiction]
# 28   150000000  [Action, Adventure, Science Fiction, Thriller]
# 29   200000000                   [Action, Adventure, Thriller]
# 31   200000000            [Action, Adventure, Science Fiction]
# 32   200000000                    [Family, Fantasy, Adventure]
# 36   210000000            [Science Fiction, Action, Adventure]
# 42   200000000                     [Animation, Family, Comedy]
# ...

# %% [markdown]
# ### The movie categories where the revenue is greater than $961,000,000.

# %%
df4[['genres','revenue']]
# Out:
#                                              genres     revenue
# 0     [Action, Adventure, Fantasy, Science Fiction]  2787965087
# 3                  [Action, Crime, Drama, Thriller]  1084939099
# 7              [Action, Adventure, Science Fiction]  1405403694
# 12                     [Adventure, Fantasy, Action]  1065659812
# 16             [Science Fiction, Action, Adventure]  1519557910
# 17                     [Adventure, Action, Fantasy]  1045713802
# 25                       [Drama, Romance, Thriller]  1845034188
# 26             [Adventure, Action, Science Fiction]  1153304495
# 28   [Action, Adventure, Science Fiction, Thriller]  1513528810
# 29                    [Action, Adventure, Thriller]  1108561013
# 31             [Action, Adventure, Science Fiction]  1215439994
# 32                     [Family, Fantasy, Adventure]  1025491110
# 36             [Science Fiction, Action, Adventure]  1091405097
# 42                      [Animation, Family, Comedy]  1066969703
# ...

# %%
df4.shape
# Out:
# (24, 20)

# %% [markdown]
# ### task 5

# %%
df.shape
# Out:
# (4803, 20)

# %% [markdown]
# ### Removing the rows with value 0 from the both budget and revenue columns

# %%
df=df.drop(df[(df['budget']==0)| (df['revenue']==0)].index)
df=df.reset_index(drop=True)
df
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 3224      27000                                       [Comedy]
# 3225      12000                        [Horror, Comedy, Crime]
# 3226      20000             [Crime, Horror, Mystery, Thriller]
# 3227       7000             [Science Fiction, Drama, Thriller]
# 3228     220000                      [Action, Crime, Thriller]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df.shape
# Out:
# (3229, 20)

# %% [markdown]
# ### task 6

# %%
highest_revenue=df.sort_values('revenue',ascending=False).head(10)
highest_revenue
# Out:
#         budget                                          genres  \
# 0    237000000   [Action, Adventure, Fantasy, Science Fiction]
# 25   200000000                      [Drama, Romance, Thriller]
# 16   220000000            [Science Fiction, Action, Adventure]
# 28   150000000  [Action, Adventure, Science Fiction, Thriller]
# 44   190000000                                        [Action]
# 7    280000000            [Action, Adventure, Science Fiction]
# 123  150000000                  [Animation, Adventure, Family]
# 31   200000000            [Action, Adventure, Science Fiction]
# 525   74000000          [Family, Animation, Adventure, Comedy]
# 26   250000000            [Adventure, Action, Science Fiction]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# 16                   http://marvel.com/avengers_movie/   24428
# ...

# %% [markdown]
# ### top 10 movies with Highest Revenue

# %%
df6_1=highest_revenue[['original_title','revenue']]
df6_1
# Out:
#                  original_title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 123                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 525                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %%
plt.barh(df6_1['original_title'],df6_1['revenue'])
plt.title('Top 10 movies with Highest Revenue')
plt.xlabel('Revenue')
plt.ylabel('Movies')
plt.show()

# %%
least_budget=df[df['budget']>0].sort_values('budget',ascending=True).head(10)
least_budget
# Out:
#       budget                                             genres  \
# 3078       1                                    [Drama, Comedy]
# 2791       4                              [Drama, Romance, War]
# 2652       7  [Thriller, Action, Horror, Science Fiction, Cr...
# 2671       7                  [Comedy, Drama, Foreign, Romance]
# 3187       8                        [Fantasy, Horror, Thriller]
# 2521      10                           [Drama, Romance, Comedy]
# 2522      10                                 [Horror, Thriller]
# 2405      11                                    [Drama, Action]
# 1694      25                                            [Drama]
# 1579      28                  [Thriller, Action, Comedy, Crime]
#
#                         homepage      id  \
# 3078                         NaN    3082
# 2791                         NaN   22649
# 2652                         NaN   13006
# 2671                         NaN   38415
# 3187                         NaN   11980
# ...

# %% [markdown]
# ### top 10 movies with least budget

# %%
df6_2=least_budget[['original_title','budget']]
df6_2
# Out:
#           original_title  budget
# 3078        Modern Times       1
# 2791  A Farewell to Arms       4
# 2652        Split Second       7
# 2671        Bran Nue Dae       7
# 3187        The Prophecy       8
# 2521         Hross í oss      10
# 2522           Nurse 3-D      10
# 2405            F.I.S.T.      11
# 1694      Angela's Ashes      25
# 1579      The 51st State      28

# %%
plt.barh(df6_2['original_title'],df6_2['budget'])
plt.title('Top 10 movies with Least Budget')
plt.xlabel('Budget')
plt.ylabel('Movies')
plt.show()

# %% [markdown]
# Interpretation:
# *Avatar has the highest revenue with $2787965087.

# %% [markdown]
# *Modern Times have the least budget with $1.

# %% [markdown]
# ### task 7

# %%
df7=df['popularity'].corr(df['budget'])
df7
# Out:
# 0.4319901360079751

# %%
fig,ax=plt.subplots(figsize=(15,7))
sb.heatmap(df.corr(),cbar=True,linewidth=0.5,annot=True,cmap='coolwarm')
plt.show()

# %%
sb.regplot(data=df,x='popularity',y='budget',label="R="+str(df7))
plt.xlabel("R="+str(df7))
plt.legend()
plt.show()

# %%
sb.regplot(data=df,y='popularity',x='budget',label="R="+str(df7))
plt.xlabel("R="+str(df7))
plt.legend()
plt.show()

# %% [markdown]
# Interpretation:
# Correlation coefficient is 0.431
# Popularities of movies related with the movie budgets are positively correlated to each other.
# As popularity increases budget of the movie is also increasing .

# %% [markdown]
# ### Task 8

# %%
#converting the string representations to actual lists of dictionaries
#import ast
#df['production_companies']=df['production_companies'].apply(ast.literal_eval)

#extracting the genre name using a lambda function 
#name=df['production_companies'].apply(lambda x:[production_companies['name'] for production_companies in x])

# %%
#df['production_companies']=name

# %%
#df_companies = df_comp['production_companies'].str.split('|').explode().reset_index(drop=True)
#df_companies

# %%
df.shape
# Out:
# (3229, 20)

# %%
#converting the string representations to actual lists of dictionaries
import json
df['production_companies']=df['production_companies'].apply(json.loads)

# %%
#extracting the genre name using a lambda function 
df['production_companies_name']=df['production_companies'].apply(lambda x:[i['name'] for i in x])

# %%
df['production_companies_name']
# Out:
# 0       [Ingenious Film Partners, Twentieth Century Fo...
# 1       [Walt Disney Pictures, Jerry Bruckheimer Films...
# 2                        [Columbia Pictures, Danjaq, B24]
# 3       [Legendary Pictures, Warner Bros., DC Entertai...
# 4                                  [Walt Disney Pictures]
#                               ...
# 3224              [Miramax Films, View Askew Productions]
# 3225                              [Dreamland Productions]
# 3226                                      [Daiei Studios]
# 3227                                          [Thinkfilm]
# 3228                                  [Columbia Pictures]
# Name: production_companies_name, Length: 3229, dtype: object

# %%
comp=df['production_companies_name'].explode().value_counts(sort=True)
comp
# Out:
# Warner Bros.                              280
# Universal Pictures                        273
# Paramount Pictures                        245
# Twentieth Century Fox Film Corporation    201
# Columbia Pictures                         167
#                                          ...
# HW Two                                      1
# Unfinished Films                            1
# Infinity Features Entertainment             1
# British Columbia Film                       1
# Daiei Studios                               1
# Name: production_companies_name, Length: 3564, dtype: int64

# %%
df_comp=df[df.production_companies!='[]']
df_comp
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 3224      27000                                       [Comedy]
# 3225      12000                        [Horror, Comedy, Crime]
# 3226      20000             [Crime, Horror, Mystery, Thriller]
# 3227       7000             [Science Fiction, Drama, Thriller]
# 3228     220000                      [Action, Crime, Thriller]
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# 1     http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
comp1=df_comp['production_companies_name'].explode().value_counts(sort=True)
comp1
# Out:
# Warner Bros.                              280
# Universal Pictures                        273
# Paramount Pictures                        245
# Twentieth Century Fox Film Corporation    201
# Columbia Pictures                         167
#                                          ...
# HW Two                                      1
# Unfinished Films                            1
# Infinity Features Entertainment             1
# British Columbia Film                       1
# Daiei Studios                               1
# Name: production_companies_name, Length: 3564, dtype: int64

# %% [markdown]
# Interpretation:
# Warner Bros. Production company has the highest number of movies with 280 movies.
# and count is 3564

# %% [markdown]
# ### task 9

# %%
comp.head(25)
# Out:
# Warner Bros.                              280
# Universal Pictures                        273
# Paramount Pictures                        245
# Twentieth Century Fox Film Corporation    201
# Columbia Pictures                         167
# New Line Cinema                           142
# Relativity Media                          100
# Walt Disney Pictures                       96
# Touchstone Pictures                        93
# Metro-Goldwyn-Mayer (MGM)                  92
# Columbia Pictures Corporation              86
# Village Roadshow Pictures                  73
# Miramax Films                              67
# DreamWorks SKG                             67
# United Artists                             64
# Regency Enterprises                        59
# Dune Entertainment                         54
# TriStar Pictures                           50
# Lionsgate                                  49
# Canal+                                     48
# ...

# %% [markdown]
# Interpretation:
# Warner Bros. Production company has the highest number of movies with 280 movies.

# %% [markdown]
# ### task 10

# %%
df10=df.sort_values('revenue',ascending=False).head(500)
df10
# Out:
#          budget                                          genres  \
# 0     237000000   [Action, Adventure, Fantasy, Science Fiction]
# 25    200000000                      [Drama, Romance, Thriller]
# 16    220000000            [Science Fiction, Action, Adventure]
# 28    150000000  [Action, Adventure, Science Fiction, Thriller]
# 44    190000000                                        [Action]
# ...         ...                                             ...
# 390    85000000                               [Comedy, Romance]
# 1556   30000000                        [Comedy, Romance, Drama]
# 669    70000000    [Adventure, Animation, Drama, Family, Music]
# 687    60000000                        [Crime, Drama, Thriller]
# 684    65000000                        [Drama, Crime, Thriller]
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# 16    http://marvel.com/avengers_movie/   24428
# ...

# %%
CM=df10[['budget','revenue','runtime']]
CM
# Out:
#          budget     revenue  runtime
# 0     237000000  2787965087    162.0
# 25    200000000  1845034188    194.0
# 16    220000000  1519557910    143.0
# 28    150000000  1513528810    124.0
# 44    190000000  1506249360    137.0
# ...         ...         ...      ...
# 390    85000000   219103655    121.0
# 1556   30000000   219076518    129.0
# 669    70000000   218613188     99.0
# 687    60000000   218340595    130.0
# 684    65000000   217764291    120.0
#
# [500 rows x 3 columns]

# %%
import statistics as st

# %%
Mean=[]
Median=[]
Mode=[]

for col in CM:
    Median.append(CM[col].median())  #calculating the median value and storing in the median list
    Mean.append(CM[col].mean())
    #Mode.append(salary_df[col].mode())
    Mode.append(st.mode(CM[col]))

row_head=['Mean','Median','Mode']
col_names=['budget','revenue','runtime']

#creating a data frame
    
d_data=pd.DataFrame([Mean,Median,Mode],columns=col_names)
d_data
# Out:
#         budget       revenue  runtime
# 0  103193736.0  4.585776e+08   118.72
# 1   95000000.0  3.630016e+08   116.00
# 2  150000000.0  2.787965e+09   115.00

# %%
d_data.insert(0,'Measures',row_head)
d_data
# Out:
#   Measures       budget       revenue  runtime
# 0     Mean  103193736.0  4.585776e+08   118.72
# 1   Median   95000000.0  3.630016e+08   116.00
# 2     Mode  150000000.0  2.787965e+09   115.00

# %%
#Separting each Column in different list
Budget_data=CM['budget'].tolist()
Revenue_data=CM['revenue'].tolist()
Runtime_data=CM['runtime'].tolist()

# %%
#Creating boxplots of 3 groups of salaries
fig=plt.figure(figsize=(10,5))
plt.boxplot([Budget_data,Revenue_data],vert=0)
plt.yticks([1,2],['budget','revenue'])
plt.show()

# %%
plt.boxplot([Runtime_data],vert=0)
plt.yticks([1],['Runtime'])
plt.show()

# %% [markdown]
# ### Interpretation:
# There are outlier's present in the runtime , revenue, budget

# %% [markdown]
# ### Task 11

# %%
df['runtime'].mean()
# Out:
# 110.72437287085785

# %%
df11=df[df['runtime']>df['runtime'].mean()]
df11
# Out:
#          budget                                         genres  \
# 0     237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1     300000000                   [Adventure, Fantasy, Action]
# 2     245000000                     [Action, Adventure, Crime]
# 3     250000000               [Action, Crime, Drama, Thriller]
# 4     260000000           [Action, Adventure, Science Fiction]
# ...         ...                                            ...
# 3191     250000                       [Comedy, Drama, Romance]
# 3197     245000                          [Drama, Romance, War]
# 3215    8500000                                        [Drama]
# 3216     100000                                        [Drama]
# 3226      20000             [Crime, Horror, Mystery, Thriller]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 1         http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df11[['original_title','runtime']]
# Out:
#                                 original_title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 3191                               Chasing Amy    113.0
# 3197                            The Big Parade    151.0
# 3215                     The Birth of a Nation    120.0
# 3216                         Facing the Giants    111.0
# 3226                                       キュア    111.0
#
# [1362 rows x 2 columns]

# %% [markdown]
# ### The names of the movies along with their runtimes for those movies that have above average runtime

# %% [markdown]
# ### Task 12

# %% [markdown]
# ### movie with highest run time

# %%
df12=df.sort_values('runtime',ascending=False)
df12
# Out:
#         budget                             genres  \
# 2034  18000000  [Crime, Drama, Thriller, History]
# 1047  31115000          [Drama, History, Romance]
# 2880   4000000              [Drama, Romance, War]
# 3158    600000      [History, Documentary, Music]
# 1032  44000000  [Action, Drama, History, Western]
# ...        ...                                ...
# 2322  12300000     [Animation, Adventure, Family]
# 3205    200000                           [Comedy]
# 1462  30000000                [Animation, Family]
# 2710   6000000                      [Documentary]
# 2797   5000000                      [Documentary]
#
#                              homepage     id  \
# 2034                              NaN  43434
# 1047                              NaN   8095
# 2880                              NaN    770
# 3158                              NaN   9459
# 1032                              NaN  10935
# ...                               ...    ...
# ...

# %%
df12[['original_title','runtime']]
# Out:
#                                   original_title  runtime
# 2034                                      Carlos    338.0
# 1047                                   Cleopatra    248.0
# 2880                          Gone with the Wind    238.0
# 3158                                   Woodstock    225.0
# 1032                               Heaven's Gate    219.0
# ...                                          ...      ...
# 2322                        The Land Before Time     69.0
# 3205                          She Done Him Wrong     66.0
# 1462                             Winnie the Pooh     63.0
# 2710    Dolphins and Whales: Tribes of the Ocean     42.0
# 2797  Sea Rex 3D: Journey to a Prehistoric World     41.0
#
# [3229 rows x 2 columns]

# %% [markdown]
# ### Carlos movie has the highest runtime with 338 mins.

# %%
df.columns

# %%
df.shape

# %% [markdown]
# ### Task 13

# %% [markdown]
# ### vote count and vote average of the movies and movie categories

# %%
df133=df.sort_values('vote_count',ascending=False).head(10)
df133
# Out:
#         budget                                             genres  \
# 95   160000000  [Action, Thriller, Science Fiction, Mystery, A...
# 65   185000000                   [Drama, Action, Crime, Thriller]
# 0    237000000      [Action, Adventure, Fantasy, Science Fiction]
# 16   220000000               [Science Fiction, Action, Adventure]
# 747   58000000                        [Action, Adventure, Comedy]
# 94   165000000                [Adventure, Drama, Science Fiction]
# 284  100000000                                   [Drama, Western]
# 93   170000000               [Action, Science Fiction, Adventure]
# 417   75000000              [Science Fiction, Adventure, Fantasy]
# 126  150000000     [Action, Adventure, Science Fiction, Thriller]
#
#                                          homepage      id  \
# 95          http://inceptionmovie.warnerbros.com/   27205
# 65   http://thedarkknight.warnerbros.com/dvdsite/     155
# 0                     http://www.avatarmovie.com/   19995
# ...

# %%
df13_1=df133[['original_title','vote_count','vote_average']]
df13_1
# Out:
#               original_title  vote_count  vote_average
# 95                 Inception       13752           8.1
# 65           The Dark Knight       12002           8.2
# 0                     Avatar       11800           7.2
# 16              The Avengers       11776           7.4
# 747                 Deadpool       10995           7.4
# 94              Interstellar       10867           8.1
# 284         Django Unchained       10099           7.8
# 93   Guardians of the Galaxy        9742           7.9
# 417         The Hunger Games        9455           6.9
# 126       Mad Max: Fury Road        9427           7.2

# %%
df13_2=df133[['genres','vote_count']]
df13_2

# %% [markdown]
# #### Incption movie has the highest vote count with 13752.

# %% [markdown]
# # Task 14

# %%
df14=df['original_language'].value_counts(sort=True)
df14
# Out:
# en    3102
# fr      25
# es      15
# ja      13
# zh      13
# de       9
# hi       7
# ru       6
# it       6
# ko       5
# cn       5
# da       4
# th       2
# nl       2
# pt       2
# id       2
# xx       1
# te       1
# is       1
# nb       1
# af       1
# pl       1
# he       1
# vi       1
# ro       1
# no       1
# fa       1
# Name: original_language, dtype: int64

# %% [markdown]
# ### English is the most original language with count 3102.
